# %%
from tvDatafeed import TvDatafeed, Interval
tv = TvDatafeed()
# Out:
# you are using nologin method, data you access may be limited

# %%
tv.get_hist(symbol='FPT',exchange='HOSE',interval=Interval.in_1_hour,n_bars=1000)
# Out:
#                        symbol         open         high          low  \
# datetime
# 2024-06-07 09:00:00  HOSE:FPT  122608.6650  123391.2735  122173.8825
# 2024-06-07 10:00:00  HOSE:FPT  122521.7085  122956.4910  122347.7955
# 2024-06-07 11:00:00  HOSE:FPT  122695.6215  123043.4475  122608.6650
# 2024-06-07 13:00:00  HOSE:FPT  122782.5780  123217.3605  122521.7085
# 2024-06-07 14:00:00  HOSE:FPT  123043.4475  123478.2300  122260.8390
# ...                       ...          ...          ...          ...
# 2025-03-25 09:00:00  HOSE:FPT  129800.0000  129900.0000  128100.0000
# 2025-03-25 10:00:00  HOSE:FPT  128100.0000  128100.0000  126500.0000
# 2025-03-25 11:00:00  HOSE:FPT  127100.0000  127800.0000  126800.0000
# 2025-03-25 13:00:00  HOSE:FPT  127200.0000  128000.0000  126900.0000
# 2025-03-25 14:00:00  HOSE:FPT  127000.0000  127100.0000  126500.0000
#
#                            close        volume
# datetime
# 2024-06-07 09:00:00  122608.6650  6.944852e+05
# ...
